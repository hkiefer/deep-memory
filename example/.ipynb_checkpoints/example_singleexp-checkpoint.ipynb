# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from deep_memory import *

# %%
import numba
import random
#simulate trajectory with single_exponential memory kernel
#particle confined in double well potential
from gle_single_exp import *


nsteps=1e7
dt=.01
kT=2.494
k=1; m=1; gamma=1; U0=1*kT; x0=0;
tau=gamma/k

v0=random.gauss(0.0,math.sqrt(kT/m))
y0=random.gauss(x0,math.sqrt(kT/gamma))

x,v,y=integrate_sing_exp(nsteps=nsteps, dt=dt, k=k, m=m, gamma=gamma,
U0=U0, x0=x0, v0=v0, y0=y0, kT=kT, scheme=1)
t = np.arange(0,len(x)*dt,dt)
#np.save("test_trj", x)
# Out:
# /usr/lib/python3/dist-packages/numba/errors.py:104: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
#checking free  energy of trajectory
hist,edges=np.histogram(x, bins=80, density=True)
pos=(edges[1:]+edges[:-1])/2

fe=-kT*np.log(hist); fe-=np.min(fe)

x2 = np.linspace(np.min(pos), np.max(pos), 100)
energy_real = U0 * ((x2)**2 - 1)**2

plt.plot(pos,fe)
plt.plot(x2,energy_real,'--')
plt.show()

# %%
#calculating xva_frame and correlation functions
xf=xframe(x,t,fix_time=True)
xvaf=compute_va(xf,correct_jumps=True)

x = xvaf["x"]
v = xvaf["v"]
a = xvaf['a']

corrv=correlation(v)
corrva = correlation(v,a)
corra = correlation(a)

m = kT/corrv[0]

force=4*U0*(x**3-x)/m
corrxu=correlation(force,x)
corrvu=correlation(force,v)
corrau=correlation(force,a)

# %%
#deep memory kernel extraction with Multi-Layer-Perceptron

trunc = 1000
X = corrv[:trunc]

#y = np.gradient(x)
y = corrva[:trunc] * m

fe = corrvu[:trunc]

X = np.array([X]).T
y = np.array([y]).T
print(X.shape, y.shape)

plt.plot(X)
plt.xscale('log')
plt.title('input')
plt.show()

plt.plot(y)
plt.xscale('log')
plt.title('output to predict')
plt.show()
# Out:
# (1000, 1) (1000, 1)

# %%
#fitting MLP (with given initial value of memory kernel)

model = MultilayerPerceptron(n_hidden=1,
    n_epochs=200,
    learning_rate=0.0001, dt = 0.01, fe = fe, optimizer = 'Rprop')

initial = torch.FloatTensor([[0.999,0.999]])

loss, model_fit_deep = model.fit(X, y, accept_bias = True, initial = initial)
# Out:
# loss in epoch 1 : 0.010960095
# loss in epoch 2 : 0.010918159
# loss in epoch 3 : 0.010867998
# loss in epoch 4 : 0.010807965
# loss in epoch 5 : 0.010736195
# loss in epoch 6 : 0.010650464
# loss in epoch 7 : 0.01054817
# loss in epoch 8 : 0.0104261935
# loss in epoch 9 : 0.010281013
# loss in epoch 10 : 0.0101084765
# loss in epoch 11 : 0.009903855
# loss in epoch 12 : 0.009661806
# loss in epoch 13 : 0.009376336
# loss in epoch 14 : 0.009041017
# loss in epoch 15 : 0.008649024
# loss in epoch 16 : 0.008193557
# loss in epoch 17 : 0.007668519
# loss in epoch 18 : 0.0070694312
# loss in epoch 19 : 0.0063950084
# loss in epoch 20 : 0.0056496877
# loss in epoch 21 : 0.00482376
# loss in epoch 22 : 0.0039164224
# loss in epoch 23 : 0.0029545776
# loss in epoch 24 : 0.001982403
# loss in epoch 25 : 0.0010766265
# loss in epoch 26 : 0.00036306205
# loss in epoch 27 : 4.0640687e-05
# loss in epoch 28 : 0.00034689522
# loss in epoch 29 : 0.00031333978
# loss in epoch 30 : 8.23055e-05
# loss in epoch 31 : 8.4942745e-05
# loss in epoch 32 : 7.6510965e-05
# loss in epoch 33 : 3.33535e-05
# loss in epoch 34 : 3.0794778e-05
# loss in epoch 35 : 3.8355487e-05
# loss in epoch 36 : 3.8288064e-05
# loss in epoch 37 : 3.132791e-05
# loss in epoch 38 : 2.9659455e-05
# loss in epoch 39 : 2.9217894e-05
# loss in epoch 40 : 2.889148e-05
# loss in epoch 41 : 2.8700777e-05
# loss in epoch 42 : 2.8109618e-05
# loss in epoch 43 : 2.7472524e-05
# loss in epoch 44 : 2.7083515e-05
# loss in epoch 45 : 2.6540256e-05
# loss in epoch 46 : 2.6259951e-05
# loss in epoch 47 : 2.6007463e-05
# loss in epoch 48 : 2.5559517e-05
# loss in epoch 49 : 2.5102981e-05
# loss in epoch 50 : 2.4659606e-05
# loss in epoch 51 : 2.403753e-05
# loss in epoch 52 : 2.3403121e-05
# loss in epoch 53 : 2.269287e-05
# loss in epoch 54 : 2.1887836e-05
# loss in epoch 55 : 2.0988262e-05
# loss in epoch 56 : 2.000531e-05
# loss in epoch 57 : 1.896407e-05
# loss in epoch 58 : 1.7911816e-05
# loss in epoch 59 : 1.734329e-05
# loss in epoch 60 : 1.6824735e-05
# loss in epoch 61 : 1.6186761e-05
# loss in epoch 62 : 1.5553143e-05
# loss in epoch 63 : 1.5114963e-05
# loss in epoch 64 : 1.4803221e-05
# loss in epoch 65 : 1.4293389e-05
# loss in epoch 66 : 1.3901169e-05
# loss in epoch 67 : 1.3493174e-05
# loss in epoch 68 : 1.3109183e-05
# loss in epoch 69 : 1.303342e-05
# loss in epoch 70 : 1.2739144e-05
# loss in epoch 71 : 1.2506803e-05
# loss in epoch 72 : 1.2298854e-05
# loss in epoch 73 : 1.2255742e-05
# loss in epoch 74 : 1.2117829e-05
# loss in epoch 75 : 1.2026571e-05
# loss in epoch 76 : 1.1947227e-05
# loss in epoch 77 : 1.1934449e-05
# loss in epoch 78 : 1.1861494e-05
# loss in epoch 79 : 1.1813859e-05
# loss in epoch 80 : 1.17754835e-05
# loss in epoch 81 : 1.1781291e-05
# loss in epoch 82 : 1.1743728e-05
# loss in epoch 83 : 1.1805216e-05
# loss in epoch 84 : 1.1805216e-05
# loss in epoch 85 : 1.1753152e-05
# loss in epoch 86 : 1.1746951e-05
# loss in epoch 87 : 1.1746951e-05
# loss in epoch 88 : 1.1742393e-05
# loss in epoch 89 : 1.1744782e-05
# loss in epoch 90 : 1.1740954e-05
# loss in epoch 91 : 1.173764e-05
# loss in epoch 92 : 1.1736217e-05
# loss in epoch 93 : 1.1734401e-05
# loss in epoch 94 : 1.1732589e-05
# loss in epoch 95 : 1.1730427e-05
# loss in epoch 96 : 1.1728054e-05
# loss in epoch 97 : 1.17254585e-05
# loss in epoch 98 : 1.172256e-05
# loss in epoch 99 : 1.1719492e-05
# loss in epoch 100 : 1.171773e-05
# loss in epoch 101 : 1.1716696e-05
# loss in epoch 102 : 1.17139525e-05
# loss in epoch 103 : 1.1714307e-05
# loss in epoch 104 : 1.1714303e-05
# loss in epoch 105 : 1.1713404e-05
# loss in epoch 106 : 1.1712869e-05
# loss in epoch 107 : 1.1712194e-05
# loss in epoch 108 : 1.1711678e-05
# loss in epoch 109 : 1.1710844e-05
# loss in epoch 110 : 1.1710421e-05
# loss in epoch 111 : 1.1710314e-05
# loss in epoch 112 : 1.170996e-05
# loss in epoch 113 : 1.1709561e-05
# loss in epoch 114 : 1.1709058e-05
# loss in epoch 115 : 1.1708597e-05
# loss in epoch 116 : 1.1708056e-05
# loss in epoch 117 : 1.17075715e-05
# loss in epoch 118 : 1.1707086e-05
# loss in epoch 119 : 1.1706678e-05
# loss in epoch 120 : 1.1706143e-05
# loss in epoch 121 : 1.1705551e-05
# loss in epoch 122 : 1.1704883e-05
# loss in epoch 123 : 1.1704142e-05
# loss in epoch 124 : 1.1703358e-05
# loss in epoch 125 : 1.1702521e-05
# loss in epoch 126 : 1.1701861e-05
# loss in epoch 127 : 1.1701633e-05
# loss in epoch 128 : 1.1700866e-05
# loss in epoch 129 : 1.1701149e-05
# loss in epoch 130 : 1.1701149e-05
# loss in epoch 131 : 1.1700778e-05
# loss in epoch 132 : 1.17005775e-05
# loss in epoch 133 : 1.1700373e-05
# loss in epoch 134 : 1.170025e-05
# loss in epoch 135 : 1.170003e-05
# loss in epoch 136 : 1.1699965e-05
# loss in epoch 137 : 1.1699993e-05
# loss in epoch 138 : 1.1699866e-05
# loss in epoch 139 : 1.1699774e-05
# loss in epoch 140 : 1.16996835e-05
# loss in epoch 141 : 1.1699592e-05
# loss in epoch 142 : 1.1699504e-05
# loss in epoch 143 : 1.1699426e-05
# loss in epoch 144 : 1.1699279e-05
# loss in epoch 145 : 1.1699209e-05
# loss in epoch 146 : 1.16991805e-05
# loss in epoch 147 : 1.169913e-05
# loss in epoch 148 : 1.1699069e-05
# loss in epoch 149 : 1.1699021e-05
# loss in epoch 150 : 1.1698946e-05
# loss in epoch 151 : 1.1698864e-05
# loss in epoch 152 : 1.1698769e-05
# loss in epoch 153 : 1.1698725e-05
# loss in epoch 154 : 1.1698652e-05
# loss in epoch 155 : 1.1698545e-05
# loss in epoch 156 : 1.1698456e-05
# loss in epoch 157 : 1.1698371e-05
# loss in epoch 158 : 1.1698267e-05
# loss in epoch 159 : 1.1698137e-05
# loss in epoch 160 : 1.1697984e-05
# loss in epoch 161 : 1.1697818e-05
# loss in epoch 162 : 1.1697764e-05
# loss in epoch 163 : 1.1697698e-05
# loss in epoch 164 : 1.1697627e-05
# loss in epoch 165 : 1.1697534e-05
# loss in epoch 166 : 1.1697488e-05
# loss in epoch 167 : 1.1697428e-05
# loss in epoch 168 : 1.16974e-05
# loss in epoch 169 : 1.16973615e-05
# loss in epoch 170 : 1.169734e-05
# loss in epoch 171 : 1.1697308e-05
# loss in epoch 172 : 1.1697263e-05
# loss in epoch 173 : 1.1697259e-05
# loss in epoch 174 : 1.1697261e-05
# loss in epoch 175 : 1.169721e-05
# loss in epoch 176 : 1.1697214e-05
# loss in epoch 177 : 1.1697161e-05
# loss in epoch 178 : 1.1697217e-05
# loss in epoch 179 : 1.1697239e-05
# loss in epoch 180 : 1.1697192e-05
# loss in epoch 181 : 1.1697164e-05
# loss in epoch 182 : 1.1697168e-05
# loss in epoch 183 : 1.1697171e-05
# loss in epoch 184 : 1.1697159e-05
# loss in epoch 185 : 1.169714e-05
# loss in epoch 186 : 1.169712e-05
# loss in epoch 187 : 1.1697133e-05
# loss in epoch 188 : 1.1697144e-05
# loss in epoch 189 : 1.1697138e-05
# loss in epoch 190 : 1.1697103e-05
# loss in epoch 191 : 1.169711e-05
# loss in epoch 192 : 1.16971e-05
# loss in epoch 193 : 1.1697106e-05
# loss in epoch 194 : 1.1697098e-05
# loss in epoch 195 : 1.1697084e-05
# loss in epoch 196 : 1.1697106e-05
# loss in epoch 197 : 1.1697119e-05
# loss in epoch 198 : 1.1697094e-05
# loss in epoch 199 : 1.1697094e-05
# loss in epoch 200 : 1.1697116e-05

# %%
kernel_index = np.arange(0,trunc*dt,0.01)
kernel_deep = model.compute_kernel(kernel_index)


plt.plot(kernel_index,kernel_deep,label = 'deep memory')

plt.xscale('log')
plt.ylabel(r'$\Gamma$(t)', fontsize = 'x-large')
plt.xlabel('t', fontsize = 'x-large')
plt.xticks(fontsize = 'x-large')
plt.yticks(fontsize = 'x-large')
plt.legend()
plt.show()

# %%
pred = model.predict(X)
plt.plot(pred)
plt.plot(y, '--')
plt.xscale('log')

# %%
#learning curve
epochs = np.arange(1,len(loss)+1)
plt.plot(epochs, loss)
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.yscale('log')
